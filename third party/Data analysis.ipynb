# %%
"""
Create a word document called "question 21" and use it to save and capture the screenshorts for question 21.
Create a python script called "student" to perform the task in questions (a) to (g).

(a) Use the table shown below to create a CSV dataset called "stud" that contains the details on students'
performance in a class and save it to the most appropriate location on your local machine.(3mrks)

GRADE  NUMBER
A       25
B       40
C       30
D       15
E       5

(b) Write a python script to import the matplotlib and pandas libraries on the python script "student"
assigning the appropriate alias name.(3mrks)

(c) Load the dataset from the CSV file into dataframe called "studgrades" (2mrks)

(d) Display the contents of the dataset for verification purposes.(2mrks)

(e) Visualise your results by using a blue bar chart, labelling both axes with the appropriate captions.(3mrks)

(f) Write a script to calculate and display the number of students in a class.(3mrks)

(g) Write a script to calculate and display the percentage performance for each other grade.(4mrks)

Save the "question 21" document and upload.(total: 20)

"""

import pandas as pd
import matplotlib.pyplot as plt

#(a) create CSV dataset
data ={ 
    'GRADE': ['A', 'B', 'C', 'D', 'E'],
    'NUMBER':[25,40,30,15,5]
}
dataframe = pd.DataFrame(data)
dataframe.to_csv('stud.csv', index=False)

#(c) Load dataset
studgrades = pd.read_csv('stud.csv')

#(d) Display contents
print(studgrades)

#(e) visualize with a bar chart
plt.figure(figsize=(10,6))
plt.bar(studgrades['GRADE'], studgrades['NUMBER'],color='green')
plt. xlabel ('Grades')
plt.ylabel('Number of Students')
plt.title('Students Performance by Grade')
plt.show()

#(f) calculate total students
total_students = studgrades['NUMBER'].sum()
print('total number of students:', total_students, "students")

#(g)Calculate the percentage for each grade
studgrades['PERCENTAGE']])
# Out:
#   GRADE  NUMBER
# 0     A      25
# 1     B      40
# 2     C      30
# 3     D      15
# 4     E       5
# total number of students: 115

# %%
import pandas as pd

#loading excel file using read_excel functions
dataframe1 = pd.read_excel('introduction.xlsx',sheet_name='THREE')
print(dataframe1)
print('\n')
dataframe2 = pd.read_excel('introduction.xlsx',sheet_name='TWO')
print(dataframe2)
# Out:
#       COUNTIES  MAIZE TOTAL BAG  PRICE PER BAG
# 0  UASIN GISHU             4000           2500
# 1      KERICHO              500           3000
# 2      TURKANA               10           5000
# 3        WAJIR                5           4500
#
#
#       COUNTIES  MAIZE  PRICE PER BAG  TOTAL
# 0  UASIN GISHU   4000           2500    NaN
# 1      KERICHO    500           3000    NaN
# 2      TURKANA     10           5000    NaN
# 3        WAJIR      5           4500    NaN
